# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('./nfl_qb.csv')

# %%
df['ap_2nd'].unique()
df.loc[df[['player'] == 'Aaron Rodgers']]
# Out:
#      year      player   tm  age pos   g  gs  wins  loses  ties  ...  rush_rk  \
# 450  1977  Bert Jones  BAL   26  QB  14  14    10      4     0  ...      128
# 518  1978    Jim Zorn  SEA   25  QB  16  16     9      7     0  ...       93
#
#      rush_att  rush_yds  rush_td  rush_lng  rush_y/a  rush_y/g  fmb  ap_1st  \
# 450        28       146        2        22       5.2      10.4    2       0
# 518        59       290        6        23       4.9      18.1   11       0
#
#      ap_2nd
# 450       1
# 518       1
#
# [2 rows x 42 columns]

# %%
sns.set(rc={'figure.figsize':(15,5)})
sns.set_style('ticks')
sns.scatterplot(data = df, x = 'year', y = 'pass_yds', hue = 'ap_2nd')
# Out:
# <AxesSubplot:xlabel='year', ylabel='pass_yds'>
