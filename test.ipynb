# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('./nfl_qb.csv')

# %%
df['ap_2nd'].unique()
# Out:
# array([0, 1])

# %%
sns.set(rc={'figure.figsize':(15,5)})
sns.set_style('ticks')
sns.scatterplot(data = df, x = 'year', y = 'pass_yds', hue = 'ap_2nd')
# Out:
# <AxesSubplot:xlabel='year', ylabel='pass_yds'>

# %%
df.columns
# Out:
# Index(['year', 'player', 'tm', 'age', 'pos', 'g', 'gs', 'wins', 'loses',
#        'ties', 'pass_rk', 'cmp', 'pass_att', 'cmp%', 'pass_yds', 'pass_td',
#        'td%', 'int', 'int%', 'pass_lng', 'pass_y/a', 'ay/a', 'y/c', 'pass_y/g',
#        'rate', 'sk', 'yards_lost_sack', 'sk%', 'ny/a', 'any/a', '4qc', 'gwd',
#        'rush_rk', 'rush_att', 'rush_yds', 'rush_td', 'rush_lng', 'rush_y/a',
#        'rush_y/g', 'fmb', 'ap_1st', 'ap_2nd'],
#       dtype='object')

# %%
df.loc[df['year'] == 2021][['player', 'rush_yds', 'rush_att', 'rush_rk']].loc[df['rush_rk'] != 0].sort_values(by = ['rush_rk'])
# Out:
#                 player  rush_yds  rush_att  rush_rk
# 3642         Tom Brady         0         0        0
# 3712       Kellen Mond         0         0        0
# 3710        Josh Rosen         0         0        0
# 3709       Jacob Eason         0         0        0
# 3701      Nick Mullens         0         0        0
# ...                ...       ...       ...      ...
# 3693        Joe Flacco         3         2      275
# 3699      Sean Mannion        14         2      288
# 3713      John Wolford        -1         2      302
# 3708     C.J. Beathard         2         1      306
# 3711  Ryan Fitzpatrick         2         1      329
#
# [75 rows x 4 columns]
